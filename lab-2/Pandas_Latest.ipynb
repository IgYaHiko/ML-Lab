# %%
# !pip install pandas

# %%
import pandas as pd

# %%
data = pd.read_csv('matches.csv')
data
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017           Pune  06-04-2017               Mumbai Indians
# 2      3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 751  752    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  753    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  754    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  755    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  756    2019      Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
type(data)
# Out:
# pandas.core.frame.DataFrame

# %%
data.values
# Out:
# array([[1, 2017, 'Hyderabad', ..., 'AY Dandekar', 'NJ Llong', nan],
#        [2, 2017, 'Pune', ..., 'A Nand Kishore', 'S Ravi', nan],
#        [3, 2017, 'Rajkot', ..., 'Nitin Menon', 'CK Nandan', nan],
#        ...,
#        [754, 2019, 'Visakhapatnam', ..., nan, nan, nan],
#        [755, 2019, 'Visakhapatnam', ..., 'Sundaram Ravi',
#         'Bruce Oxenford', 'Chettithody Shamshuddin'],
#        [756, 2019, 'Hyderabad', ..., 'Nitin Menon', 'Ian Gould',
#         'Nigel Llong']], dtype=object)

# %%
data.values[1]
# Out:
# array([2, 2017, 'Pune', '06-04-2017', 'Mumbai Indians',
#        'Rising Pune Supergiant', 'Rising Pune Supergiant', 'field',
#        'normal', 0, 'Rising Pune Supergiant', 0, 7, 'SPD Smith',
#        'Maharashtra Cricket Association Stadium', 'A Nand Kishore',
#        'S Ravi', nan], dtype=object)

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.head(8)
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5   6    2017  Hyderabad  09-04-2017                Gujarat Lions
# 6   7    2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7   8    2017     Indore  10-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# ...

# %%
data.tail()
# Out:
#       id  season           city        date                  team1  \
# 751  752    2019         Mumbai  05-05-2019  Kolkata Knight Riders
# 752  753    2019        Chennai  07-05-2019    Chennai Super Kings
# 753  754    2019  Visakhapatnam  08-05-2019    Sunrisers Hyderabad
# 754  755    2019  Visakhapatnam  10-05-2019         Delhi Capitals
# 755  756    2019      Hyderabad  12-05-2019         Mumbai Indians
#
#                    team2          toss_winner toss_decision  result  \
# 751       Mumbai Indians       Mumbai Indians         field  normal
# 752       Mumbai Indians  Chennai Super Kings           bat  normal
# 753       Delhi Capitals       Delhi Capitals         field  normal
# 754  Chennai Super Kings  Chennai Super Kings         field  normal
# 755  Chennai Super Kings       Mumbai Indians           bat  normal
#
#      dl_applied               winner  win_by_runs  win_by_wickets  \
# 751           0       Mumbai Indians            0               9
# ...

# %%
data.sample()   ## 1 random record
# Out:
#       id  season    city        date           team1                  team2  \
# 433  434    2013  Mumbai  07-05-2013  Mumbai Indians  Kolkata Knight Riders
#
#         toss_winner toss_decision  result  dl_applied          winner  \
# 433  Mumbai Indians           bat  normal           0  Mumbai Indians
#
#      win_by_runs  win_by_wickets player_of_match             venue  \
# 433           65               0    SR Tendulkar  Wankhede Stadium
#
#              umpire1 umpire2 umpire3
# 433  HDPK Dharmasena  S Ravi     NaN

# %%
data.sample(5)
# Out:
#       id  season       city        date                  team1  \
# 338  339    2012       Pune  24-04-2012          Pune Warriors
# 654  655    2018  Bengaluru  21-04-2018       Delhi Daredevils
# 372  373    2012  Hyderabad  18-05-2012       Rajasthan Royals
# 215  216    2010     Nagpur  10-04-2010    Chennai Super Kings
# 513  514    2014    Kolkata  27-05-2014  Kolkata Knight Riders
#
#                            team2                  toss_winner toss_decision  \
# 338             Delhi Daredevils                Pune Warriors           bat
# 654  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 372              Deccan Chargers             Rajasthan Royals           bat
# 215              Deccan Chargers          Chennai Super Kings           bat
# 513              Kings XI Punjab              Kings XI Punjab         field
#
#      result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.sample(7,random_state=9)
# Out:
#       id  season           city        date             team1  \
# 444  445    2013         Ranchi  15-05-2013     Pune Warriors
# 450  451    2013           Pune  19-05-2013     Pune Warriors
# 628  629    2016  Visakhapatnam  21-05-2016   Kings XI Punjab
# 708  709    2019         Mohali  01-04-2019   Kings XI Punjab
# 755  756    2019      Hyderabad  12-05-2019    Mumbai Indians
# 661  662    2018          Delhi  27-04-2018  Delhi Daredevils
# 565  566    2015     Chandigarh  13-05-2015   Kings XI Punjab
#
#                            team2                  toss_winner toss_decision  \
# 444        Kolkata Knight Riders        Kolkata Knight Riders         field
# 450             Delhi Daredevils                Pune Warriors           bat
# 628      Rising Pune Supergiants              Kings XI Punjab           bat
# 708               Delhi Capitals               Delhi Capitals         field
# 755          Chennai Super Kings               Mumbai Indians           bat
# ...

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
data.index
# Out:
# RangeIndex(start=0, stop=756, step=1)

# %%
data.dtypes
# Out:
# id                  int64
# season              int64
# city               object
# date               object
# team1              object
# team2              object
# toss_winner        object
# toss_decision      object
# result             object
# dl_applied          int64
# winner             object
# win_by_runs         int64
# win_by_wickets      int64
# player_of_match    object
# venue              object
# umpire1            object
# umpire2            object
# umpire3            object
# dtype: object

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
### Access Columns (Subset of dataframe)

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data['city']   ## series
# Out:
# 0          Hyderabad
# 1               Pune
# 2             Rajkot
# 3             Indore
# 4          Bangalore
#            ...
# 751           Mumbai
# 752          Chennai
# 753    Visakhapatnam
# 754    Visakhapatnam
# 755        Hyderabad
# Name: city, Length: 756, dtype: object

# %%
type(data['city'])
# Out:
# pandas.core.series.Series

# %%
data['city'].values
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Hyderabad',
#        'Mumbai', 'Indore', 'Pune', 'Mumbai', 'Kolkata', 'Bangalore',
#        'Rajkot', 'Kolkata', 'Delhi', 'Mumbai', 'Bangalore', 'Delhi',
#        'Hyderabad', 'Rajkot', 'Hyderabad', 'Indore', 'Kolkata', 'Mumbai',
#        'Pune', 'Rajkot', 'Kolkata', 'Mumbai', 'Pune', 'Bangalore',
#        'Kolkata', 'Chandigarh', 'Pune', 'Rajkot', 'Chandigarh',
#        'Hyderabad', 'Mumbai', 'Pune', 'Delhi', 'Kolkata', 'Delhi',
#        'Bangalore', 'Hyderabad', 'Delhi', 'Bangalore', 'Chandigarh',
#        'Hyderabad', 'Chandigarh', 'Kanpur', 'Mumbai', 'Delhi', 'Kanpur',
#        'Kolkata', 'Pune', 'Delhi', 'Mumbai', 'Bangalore', 'Bangalore',
#        'Hyderabad', 'Bangalore', 'Chandigarh', 'Delhi', 'Mumbai',
#        'Kolkata', 'Jaipur', 'Hyderabad', 'Chennai', 'Hyderabad',
#        'Chandigarh', 'Bangalore', 'Chennai', 'Mumbai', 'Chandigarh',
#        'Bangalore', 'Kolkata', 'Delhi', 'Hyderabad', 'Jaipur', 'Chennai',
# ...

# %%
data[['city','team1','team2', 'result']]
# Out:
#               city                        team1                        team2  \
# 0        Hyderabad          Sunrisers Hyderabad  Royal Challengers Bangalore
# 1             Pune               Mumbai Indians       Rising Pune Supergiant
# 2           Rajkot                Gujarat Lions        Kolkata Knight Riders
# 3           Indore       Rising Pune Supergiant              Kings XI Punjab
# 4        Bangalore  Royal Challengers Bangalore             Delhi Daredevils
# ..             ...                          ...                          ...
# 751         Mumbai        Kolkata Knight Riders               Mumbai Indians
# 752        Chennai          Chennai Super Kings               Mumbai Indians
# 753  Visakhapatnam          Sunrisers Hyderabad               Delhi Capitals
# 754  Visakhapatnam               Delhi Capitals          Chennai Super Kings
# 755      Hyderabad               Mumbai Indians          Chennai Super Kings
#
#      result
# 0    normal
# 1    normal
# ...

# %%
data[['city']]   ## dataframe
# Out:
#               city
# 0        Hyderabad
# 1             Pune
# 2           Rajkot
# 3           Indore
# 4        Bangalore
# ..             ...
# 751         Mumbai
# 752        Chennai
# 753  Visakhapatnam
# 754  Visakhapatnam
# 755      Hyderabad
#
# [756 rows x 1 columns]

# %%
type(data[['city']])
# Out:
# pandas.core.frame.DataFrame

# %%
### Access rows

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.iloc[:,:]   ## row,coln
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017           Pune  06-04-2017               Mumbai Indians
# 2      3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 751  752    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  753    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  754    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  755    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  756    2019      Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.iloc[3:11,:]
# Out:
#     id  season       city        date                        team1  \
# 3    4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4    5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
# 5    6    2017  Hyderabad  09-04-2017                Gujarat Lions
# 6    7    2017     Mumbai  09-04-2017        Kolkata Knight Riders
# 7    8    2017     Indore  10-04-2017  Royal Challengers Bangalore
# 8    9    2017       Pune  11-04-2017             Delhi Daredevils
# 9   10    2017     Mumbai  12-04-2017          Sunrisers Hyderabad
# 10  11    2017    Kolkata  13-04-2017              Kings XI Punjab
#
#                      team2                  toss_winner toss_decision  result  \
# 3          Kings XI Punjab              Kings XI Punjab         field  normal
# 4         Delhi Daredevils  Royal Challengers Bangalore           bat  normal
# 5      Sunrisers Hyderabad          Sunrisers Hyderabad         field  normal
# ...

# %%
data.iloc[3:11,4:6]
# Out:
#                           team1                   team2
# 3        Rising Pune Supergiant         Kings XI Punjab
# 4   Royal Challengers Bangalore        Delhi Daredevils
# 5                 Gujarat Lions     Sunrisers Hyderabad
# 6         Kolkata Knight Riders          Mumbai Indians
# 7   Royal Challengers Bangalore         Kings XI Punjab
# 8              Delhi Daredevils  Rising Pune Supergiant
# 9           Sunrisers Hyderabad          Mumbai Indians
# 10              Kings XI Punjab   Kolkata Knight Riders

# %%
data.iloc[[3,10,15],4:6]
# Out:
#                      team1                  team2
# 3   Rising Pune Supergiant        Kings XI Punjab
# 10         Kings XI Punjab  Kolkata Knight Riders
# 15           Gujarat Lions         Mumbai Indians

# %%
data.iloc[[3,10,15],[4,7,8]]
# Out:
#                      team1 toss_decision  result
# 3   Rising Pune Supergiant         field  normal
# 10         Kings XI Punjab         field  normal
# 15           Gujarat Lions         field  normal

# %%
data.iloc[[3,10],[4,7]]
# Out:
#                      team1 toss_decision
# 3   Rising Pune Supergiant         field
# 10         Kings XI Punjab         field

# %%
data.iloc[[3,10,15]][['team1','toss_decision','result']]
# Out:
#                      team1 toss_decision  result
# 3   Rising Pune Supergiant         field  normal
# 10         Kings XI Punjab         field  normal
# 15           Gujarat Lions         field  normal

# %%
### statistical info
data.describe()
# Out:
#                id       season  dl_applied  win_by_runs  win_by_wickets
# count  756.000000   756.000000  756.000000   756.000000      756.000000
# mean   378.500000  2013.444444    0.025132    13.283069        3.350529
# std    218.382692     3.366895    0.156630    23.471144        3.387963
# min      1.000000  2008.000000    0.000000     0.000000        0.000000
# 25%    189.750000  2011.000000    0.000000     0.000000        0.000000
# 50%    378.500000  2013.000000    0.000000     0.000000        4.000000
# 75%    567.250000  2016.000000    0.000000    19.000000        6.000000
# max    756.000000  2019.000000    1.000000   146.000000       10.000000

# %%
### Handle Missing(Nan) values

# %%
data.columns
# Out:
# Index(['id', 'season', 'city', 'date', 'team1', 'team2', 'toss_winner',
#        'toss_decision', 'result', 'dl_applied', 'winner', 'win_by_runs',
#        'win_by_wickets', 'player_of_match', 'venue', 'umpire1', 'umpire2',
#        'umpire3'],
#       dtype='object')

# %%
### Count of missing values
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
data_null = pd.DataFrame(data.isnull().sum())
import seaborn as sns
sns.heatmap(data_null,annot=True,cmap='Blues')
# Out:
# <AxesSubplot: >

# %%
### 1. Remove rows/cols having missing values
### 2. We can fill that value with some appropriate value (mean, median, random)

# %%
## remove null rows/cols

# %%
data.shape
# Out:
# (756, 18)

# %%
data.dropna(axis=0)   ## drops all null rows (default)
# Out:
#       id  season           city        date                        team1  \
# 636  637    2018         Mumbai  07-04-2018               Mumbai Indians
# 637  638    2018         Mohali  08-04-2018             Delhi Daredevils
# 638  639    2018        Kolkata  08-04-2018  Royal Challengers Bangalore
# 639  640    2018      Hyderabad  09-04-2018             Rajasthan Royals
# 640  641    2018        Chennai  10-04-2018        Kolkata Knight Riders
# ..   ...     ...            ...         ...                          ...
# 750  751    2019         Mohali  05-05-2019          Chennai Super Kings
# 751  752    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  753    2019        Chennai  07-05-2019          Chennai Super Kings
# 754  755    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  756    2019      Hyderabad  12-05-2019               Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
data.dropna(axis=1)  ## drops all  columns having null values
# Out:
#       id  season        date                        team1  \
# 0      1    2017  05-04-2017          Sunrisers Hyderabad
# 1      2    2017  06-04-2017               Mumbai Indians
# 2      3    2017  07-04-2017                Gujarat Lions
# 3      4    2017  08-04-2017       Rising Pune Supergiant
# 4      5    2017  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...         ...                          ...
# 751  752    2019  05-05-2019        Kolkata Knight Riders
# 752  753    2019  07-05-2019          Chennai Super Kings
# 753  754    2019  08-05-2019          Sunrisers Hyderabad
# 754  755    2019  10-05-2019               Delhi Capitals
# 755  756    2019  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# 0    Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1         Rising Pune Supergiant       Rising Pune Supergiant         field
# ...

# %%
data.dropna(axis=0, how = "any")
# Out:
#       id  season           city        date                        team1  \
# 636  637    2018         Mumbai  07-04-2018               Mumbai Indians
# 637  638    2018         Mohali  08-04-2018             Delhi Daredevils
# 638  639    2018        Kolkata  08-04-2018  Royal Challengers Bangalore
# 639  640    2018      Hyderabad  09-04-2018             Rajasthan Royals
# 640  641    2018        Chennai  10-04-2018        Kolkata Knight Riders
# ..   ...     ...            ...         ...                          ...
# 750  751    2019         Mohali  05-05-2019          Chennai Super Kings
# 751  752    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  753    2019        Chennai  07-05-2019          Chennai Super Kings
# 754  755    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  756    2019      Hyderabad  12-05-2019               Mumbai Indians
#
#                      team2            toss_winner toss_decision  result  \
# ...

# %%
data.dropna(axis=0, how = "all")
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017           Pune  06-04-2017               Mumbai Indians
# 2      3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 751  752    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  753    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  754    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  755    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  756    2019      Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 756 entries, 0 to 755
# Data columns (total 18 columns):
#  #   Column           Non-Null Count  Dtype
# ---  ------           --------------  -----
#  0   id               756 non-null    int64
#  1   season           756 non-null    int64
#  2   city             749 non-null    object
#  3   date             756 non-null    object
#  4   team1            756 non-null    object
#  5   team2            756 non-null    object
#  6   toss_winner      756 non-null    object
#  7   toss_decision    756 non-null    object
#  8   result           756 non-null    object
#  9   dl_applied       756 non-null    int64
#  10  winner           752 non-null    object
#  11  win_by_runs      756 non-null    int64
#  12  win_by_wickets   756 non-null    int64
#  13  player_of_match  752 non-null    object
#  14  venue            756 non-null    object
#  15  umpire1          754 non-null    object
#  16  umpire2          754 non-null    object
# ...

# %%
data.isnull().sum()
# Out:
# id                   0
# season               0
# city                 7
# date                 0
# team1                0
# team2                0
# toss_winner          0
# toss_decision        0
# result               0
# dl_applied           0
# winner               4
# win_by_runs          0
# win_by_wickets       0
# player_of_match      4
# venue                0
# umpire1              2
# umpire2              2
# umpire3            637
# dtype: int64

# %%
data.dropna(axis=0, how = "any", subset = ['umpire1','umpire2'])
# Out:
#       id  season           city        date                   team1  \
# 0      1    2017      Hyderabad  05-04-2017     Sunrisers Hyderabad
# 1      2    2017           Pune  06-04-2017          Mumbai Indians
# 2      3    2017         Rajkot  07-04-2017           Gujarat Lions
# 3      4    2017         Indore  08-04-2017  Rising Pune Supergiant
# 5      6    2017      Hyderabad  09-04-2017           Gujarat Lions
# ..   ...     ...            ...         ...                     ...
# 750  751    2019         Mohali  05-05-2019     Chennai Super Kings
# 751  752    2019         Mumbai  05-05-2019   Kolkata Knight Riders
# 752  753    2019        Chennai  07-05-2019     Chennai Super Kings
# 754  755    2019  Visakhapatnam  10-05-2019          Delhi Capitals
# 755  756    2019      Hyderabad  12-05-2019          Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
### fill the null values

# %%
mean_runs = round(data['win_by_runs'].mean())
data['win_by_runs'] = data['win_by_runs'].fillna(mean_runs)

# %%
data = data.fillna("NP")

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
data.isnull().sum()
# Out:
# id                 0
# season             0
# city               0
# date               0
# team1              0
# team2              0
# toss_winner        0
# toss_decision      0
# result             0
# dl_applied         0
# winner             0
# win_by_runs        0
# win_by_wickets     0
# player_of_match    0
# venue              0
# umpire1            0
# umpire2            0
# umpire3            0
# dtype: int64

# %%
data_null = pd.DataFrame(data.isnull().sum())
import seaborn as sns
sns.heatmap(data_null,annot=True,cmap='Blues')
# Out:
# <AxesSubplot: >

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
### Filter data

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
filter = data['city'] == 'Pune'
data[filter]
# Out:
#       id  season  city        date                        team1  \
# 1      2    2017  Pune  06-04-2017               Mumbai Indians
# 8      9    2017  Pune  11-04-2017             Delhi Daredevils
# 24    25    2017  Pune  22-04-2017          Sunrisers Hyderabad
# 28    29    2017  Pune  26-04-2017       Rising Pune Supergiant
# 32    33    2017  Pune  29-04-2017       Rising Pune Supergiant
# 37    38    2017  Pune  01-05-2017                Gujarat Lions
# 53    54    2017  Pune  14-05-2017              Kings XI Punjab
# 314  315    2012  Pune  08-04-2012                Pune Warriors
# 323  324    2012  Pune  14-04-2012          Chennai Super Kings
# 338  339    2012  Pune  24-04-2012                Pune Warriors
# 340  341    2012  Pune  26-04-2012              Deccan Chargers
# 350  351    2012  Pune  03-05-2012               Mumbai Indians
# 357  358    2012  Pune  08-05-2012                Pune Warriors
# 361  362    2012  Pune  11-05-2012  Royal Challengers Bangalore
# ...

# %%
print(len(data[filter]))
# Out:
# 38

# %%
filter = data['win_by_runs']>100
data[filter]
# Out:
#       id  season        city        date                        team1  \
# 43    44    2017       Delhi  06-05-2017               Mumbai Indians
# 59    60    2008   Bangalore  18-04-2008        Kolkata Knight Riders
# 114  115    2008      Mumbai  30-05-2008             Rajasthan Royals
# 295  296    2011  Dharamsala  17-05-2011              Kings XI Punjab
# 410  411    2013   Bangalore  23-04-2013  Royal Challengers Bangalore
# 556  557    2015   Bangalore  06-05-2015  Royal Challengers Bangalore
# 619  620    2016   Bangalore  14-05-2016  Royal Challengers Bangalore
# 676  677    2018     Kolkata  09-05-2018               Mumbai Indians
# 706  707    2019   Hyderabad  31-03-2019          Sunrisers Hyderabad
#
#                            team2                  toss_winner toss_decision  \
# 43              Delhi Daredevils             Delhi Daredevils         field
# 59   Royal Challengers Bangalore  Royal Challengers Bangalore         field
# ...

# %%
print(len(data[filter]))
# Out:
# 9

# %%
filter1 = data['city'] == 'Pune'
filter2 = data['win_by_runs']>70
data[filter1 & filter2]
# Out:
#       id  season  city        date                        team1  \
# 8      9    2017  Pune  11-04-2017             Delhi Daredevils
# 573  574    2015  Pune  20-05-2015  Royal Challengers Bangalore
#
#                       team2                  toss_winner toss_decision  \
# 8    Rising Pune Supergiant       Rising Pune Supergiant         field
# 573        Rajasthan Royals  Royal Challengers Bangalore           bat
#
#      result  dl_applied                       winner  win_by_runs  \
# 8    normal           0             Delhi Daredevils           97
# 573  normal           0  Royal Challengers Bangalore           71
#
#      win_by_wickets player_of_match                                    venue  \
# 8                 0       SV Samson  Maharashtra Cricket Association Stadium
# 573               0  AB de Villiers  Maharashtra Cricket Association Stadium
#
#           umpire1        umpire2 umpire3
# 8     AY Dandekar         S Ravi      NP
# ...

# %%
data.head(2)
# Out:
#    id  season       city        date                team1  \
# 0   1    2017  Hyderabad  05-04-2017  Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017       Mumbai Indians
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
#
#    result  dl_applied                  winner  win_by_runs  win_by_wickets  \
# 0  normal           0     Sunrisers Hyderabad           35               0
# 1  normal           0  Rising Pune Supergiant            0               7
#
#   player_of_match                                      venue         umpire1  \
# 0    Yuvraj Singh  Rajiv Gandhi International Stadium, Uppal     AY Dandekar
# 1       SPD Smith    Maharashtra Cricket Association Stadium  A Nand Kishore
#
#     umpire2 umpire3
# 0  NJ Llong      NP
# 1    S Ravi      NP

# %%
data['city'].value_counts()
# Out:
# Mumbai            101
# Kolkata            77
# Delhi              74
# Bangalore          66
# Hyderabad          64
# Chennai            57
# Jaipur             47
# Chandigarh         46
# Pune               38
# Durban             15
# Bengaluru          14
# Visakhapatnam      13
# Ahmedabad          12
# Centurion          12
# Rajkot             10
# Mohali             10
# Indore              9
# Dharamsala          9
# Johannesburg        8
# Cape Town           7
# Ranchi              7
# Abu Dhabi           7
# Cuttack             7
# NP                  7
# Port Elizabeth      7
# Sharjah             6
# Raipur              6
# Kochi               5
# Kanpur              4
# Nagpur              3
# Kimberley           3
# East London         3
# Bloemfontein        2
# Name: city, dtype: int64

# %%
data['winner'].value_counts()
# Out:
# Mumbai Indians                 109
# Chennai Super Kings            100
# Kolkata Knight Riders           92
# Royal Challengers Bangalore     84
# Kings XI Punjab                 82
# Rajasthan Royals                75
# Delhi Daredevils                67
# Sunrisers Hyderabad             58
# Deccan Chargers                 29
# Gujarat Lions                   13
# Pune Warriors                   12
# Rising Pune Supergiant          10
# Delhi Capitals                  10
# Kochi Tuskers Kerala             6
# Rising Pune Supergiants          5
# NP                               4
# Name: winner, dtype: int64

# %%
len(data[data['city']=="Delhi"])
# Out:
# 74

# %%
data['city'].value_counts()['Delhi']
# Out:
# 74

# %%
data['city'].unique()
# Out:
# array(['Hyderabad', 'Pune', 'Rajkot', 'Indore', 'Bangalore', 'Mumbai',
#        'Kolkata', 'Delhi', 'Chandigarh', 'Kanpur', 'Jaipur', 'Chennai',
#        'Cape Town', 'Port Elizabeth', 'Durban', 'Centurion',
#        'East London', 'Johannesburg', 'Kimberley', 'Bloemfontein',
#        'Ahmedabad', 'Cuttack', 'Nagpur', 'Dharamsala', 'Kochi',
#        'Visakhapatnam', 'Raipur', 'Ranchi', 'Abu Dhabi', 'Sharjah', 'NP',
#        'Mohali', 'Bengaluru'], dtype=object)

# %%
### drop row or column

# %%
data.head()
# Out:
#    id  season       city        date                        team1  \
# 0   1    2017  Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1   2    2017       Pune  06-04-2017               Mumbai Indians
# 2   3    2017     Rajkot  07-04-2017                Gujarat Lions
# 3   4    2017     Indore  08-04-2017       Rising Pune Supergiant
# 4   5    2017  Bangalore  08-04-2017  Royal Challengers Bangalore
#
#                          team2                  toss_winner toss_decision  \
# 0  Royal Challengers Bangalore  Royal Challengers Bangalore         field
# 1       Rising Pune Supergiant       Rising Pune Supergiant         field
# 2        Kolkata Knight Riders        Kolkata Knight Riders         field
# 3              Kings XI Punjab              Kings XI Punjab         field
# 4             Delhi Daredevils  Royal Challengers Bangalore           bat
#
#    result  dl_applied                       winner  win_by_runs  \
# ...

# %%
### remove complete column
data.drop(['umpire1','umpire2','umpire3'],axis=1)
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017           Pune  06-04-2017               Mumbai Indians
# 2      3    2017         Rajkot  07-04-2017                Gujarat Lions
# 3      4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 4      5    2017      Bangalore  08-04-2017  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 751  752    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  753    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  754    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  755    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  756    2019      Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...

# %%
### remove complete row
data.drop([2,4,6],axis=0)
# Out:
#       id  season           city        date                        team1  \
# 0      1    2017      Hyderabad  05-04-2017          Sunrisers Hyderabad
# 1      2    2017           Pune  06-04-2017               Mumbai Indians
# 3      4    2017         Indore  08-04-2017       Rising Pune Supergiant
# 5      6    2017      Hyderabad  09-04-2017                Gujarat Lions
# 7      8    2017         Indore  10-04-2017  Royal Challengers Bangalore
# ..   ...     ...            ...         ...                          ...
# 751  752    2019         Mumbai  05-05-2019        Kolkata Knight Riders
# 752  753    2019        Chennai  07-05-2019          Chennai Super Kings
# 753  754    2019  Visakhapatnam  08-05-2019          Sunrisers Hyderabad
# 754  755    2019  Visakhapatnam  10-05-2019               Delhi Capitals
# 755  756    2019      Hyderabad  12-05-2019               Mumbai Indians
#
#                            team2                  toss_winner toss_decision  \
# ...
